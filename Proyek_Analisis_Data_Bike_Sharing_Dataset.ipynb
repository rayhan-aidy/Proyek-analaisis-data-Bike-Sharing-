# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Muhammad Rayhan Aidy Abshar]
# - **Email:** [rayhanaidy03@gmail.com]
# - **ID Dicoding:** [Muhammad Rayhan Aidy Abshar]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana Tren penggunaan sepeda secara bulanan
# - bagaimana dampak musin dan cuaca terhadap penggunaan seopeda
# - bagaimana pola perilaku dari penggguna langganan dan tidak langganan

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
import pandas as pd

# Tautan unduhan langsung Google Drive
url = 'https://drive.google.com/uc?export=download&id=1DEAX6Zw46GyLzlC2XulkLdIQCpREdXRl'

# Membaca file CSV
day = pd.read_csv(url)

# Menampilkan data
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
import pandas as pd

# Tautan unduhan langsung Google Drive
url = 'https://drive.google.com/uc?export=download&id=1NlvkobNiWLBTJkJZ0SC1bRhZhneNrinp'

# Membaca file CSV
hour = pd.read_csv(url)

# Menampilkan data
hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Assesing dataset day

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
print('data duplikat  : ', day.duplicated().sum())
print('data null      : ', day.isnull().sum())
# Out:
# data duplikat  :  0
# data null      :  instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
print('data duplikat  : ', hour.duplicated().sum())
print('data null      : ', hour.isnull().sum())
# Out:
# data duplikat  :  0
# data null      :  instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Cleaning Data

# %%
import pandas as pd
# there is no missing value and duplicate value in both dataset
# change dteday to datetime
day['dteday'] = pd.to_datetime(day['dteday'])
hour['dteday'] = pd.to_datetime(hour['dteday'])

# %%
#merename nama pada setiap kolom agar lebih jelas di baca

day = day.rename(columns={
    'instant': 'record_id',
    'dteday': 'date_day',
    'season': 'season_num',
    'yr': 'year',
    'mnth': 'month',
    'holiday': 'is_holiday',
    'weekday': 'day_of_week',
    'workingday': 'is_workingday',
    'weathersit': 'weather_condition',
    'temp': 'normalized_temp',
    'atemp': 'normalized_feeling_temp',
    'hum': 'normalized_humidity',
    'windspeed': 'normalized_windspeed',
    'casual': 'casual_users',
    'registered': 'registered_users',
    'cnt': 'total_users'
})

hour = hour.rename(columns={
    'instant': 'record_id',
    'dteday': 'date_day',
    'season': 'season_num',
    'yr': 'year',
    'mnth': 'month',
    'hr': 'hour',
    'holiday': 'is_holiday',
    'weekday': 'day_of_week',
    'workingday': 'is_workingday',
    'weathersit': 'weather_condition',
    'temp': 'normalized_temp',
    'atemp': 'normalized_feeling_temp',
    'hum': 'normalized_humidity',
    'windspeed': 'normalized_windspeed',
    'casual': 'casual_users',
    'registered': 'registered_users',
    'cnt': 'total_users'
})

# %%
# ubah season dari angka menjadi nama musim
day['season_num'] = day['season_num'].replace({1: 'springer', 2: 'summer', 3: 'fall', 4: 'winter'})
hour['season_num'] = hour['season_num'].replace({1: 'springer', 2: 'summer', 3: 'fall', 4: 'winter'})

# %%
# ubah tahun dari angka menjadi tahun
day['year'] = day['year'].replace({0: 2011, 1: 2012})
hour['year'] = hour['year'].replace({0: 2011, 1: 2012})

# %%
import pandas as pd
# ubah bulan dari angka menjadi nama bulan
day['month'] = day['month'].replace({1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'})
hour['month'] = hour['month'].replace({1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'})

# ubah hari dari angka menjadi nama hari
day['day_of_week'] = day['day_of_week'].replace({0: 'Sun', 1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat'})
hour['day_of_week'] = hour['day_of_week'].replace({0: 'Sun', 1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat'})

# ubah cuaca dari angka menjadi keterangan cuaca
day['weather_condition'] = day['weather_condition'].replace({1: 'Clear', 2: 'Mist', 3: 'Light Snow', 4: 'Heavy Rain'})
hour['weather_condition'] = hour['weather_condition'].replace({1: 'Clear', 2: 'Mist', 3: 'Light Snow', 4: 'Heavy Rain'})

# ubah hari kerja dari angka menjadi keterangan hari kerja
day['is_workingday'] = day['is_workingday'].replace({0: 'Holiday', 1: 'Working Day'})
hour['is_workingday'] = hour['is_workingday'].replace({0: 'Holiday', 1: 'Working Day'})

# ubah liburan dari angka menjadi keterangan liburan
day['is_holiday'] = day['is_holiday'].replace({0: 'Not Holiday', 1: 'Holiday'})
hour['is_holiday'] = hour['is_holiday'].replace({0: 'Not Holiday', 1: 'Holiday'})

# mengubah urutan bulan
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
day['month'] = pd.Categorical(day['month'], categories=month_order, ordered=True)
hour['month'] = pd.Categorical(hour['month'], categories=month_order, ordered=True)

# %%
# ubah cuaca dari angka menjadi keterangan cuaca
day['weather_condition'] = day['weather_condition'].replace({1: 'Clear', 2: 'Mist', 3: 'Light Snow', 4: 'Heavy Rain'})
hour['weather_condition'] = hour['weather_condition'].replace({1: 'Clear', 2: 'Mist', 3: 'Light Snow', 4: 'Heavy Rain'})

# %%
day.head()
# Out:
#    record_id   date_day season_num  year month   is_holiday day_of_week  \
# 0          1 2011-01-01   springer  2011   Jan  Not Holiday         Sat
# 1          2 2011-01-02   springer  2011   Jan  Not Holiday         Sun
# 2          3 2011-01-03   springer  2011   Jan  Not Holiday         Mon
# 3          4 2011-01-04   springer  2011   Jan  Not Holiday         Tue
# 4          5 2011-01-05   springer  2011   Jan  Not Holiday         Wed
#
#   is_workingday weather_condition  normalized_temp  normalized_feeling_temp  \
# 0       Holiday              Mist         0.344167                 0.363625
# 1       Holiday              Mist         0.363478                 0.353739
# 2   Working Day             Clear         0.196364                 0.189405
# 3   Working Day             Clear         0.200000                 0.212122
# 4   Working Day             Clear         0.226957                 0.229270
#
# ...

# %%
hour.head()
# Out:
#    record_id   date_day season_num  year month  hour   is_holiday day_of_week  \
# 0          1 2011-01-01   springer  2011   Jan     0  Not Holiday         Sat
# 1          2 2011-01-01   springer  2011   Jan     1  Not Holiday         Sat
# 2          3 2011-01-01   springer  2011   Jan     2  Not Holiday         Sat
# 3          4 2011-01-01   springer  2011   Jan     3  Not Holiday         Sat
# 4          5 2011-01-01   springer  2011   Jan     4  Not Holiday         Sat
#
#   is_workingday weather_condition  normalized_temp  normalized_feeling_temp  \
# 0       Holiday             Clear             0.24                   0.2879
# 1       Holiday             Clear             0.22                   0.2727
# 2       Holiday             Clear             0.22                   0.2727
# 3       Holiday             Clear             0.24                   0.2879
# 4       Holiday             Clear             0.24                   0.2879
#
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Dataset DAY

# %%
day_group = day.groupby('day_of_week')[['casual_users','registered_users']].sum()
day_group
# Out:
#              casual_users  registered_users
# day_of_week
# Fri                 78238            409552
# Mon                 70784            384719
# Sat                153852            323955
# Sun                140521            303506
# Thu                 61460            423935
# Tue                 57843            411266
# Wed                 57319            415729

# %%
# Melihat total pengguna sepeda berdasarkan hari libur
total_pengguna_per_hari_libur = day.groupby('is_holiday')[['casual_users','registered_users','total_users']].sum().reset_index()
total_pengguna_per_hari_libur
# Out:
#     is_holiday  casual_users  registered_users  total_users
# 0      Holiday         22359             56076        78435
# 1  Not Holiday        597658           2616586      3214244

# %%
# Melihat rata-rata pengguna sepeda berdasarkan kondisi cuaca
rata_rata_pengguna_per_kondisi_cuaca = day.groupby('weather_condition')[['casual_users','registered_users','total_users']].mean().reset_index()
rata_rata_pengguna_per_kondisi_cuaca
# Out:
#   weather_condition  casual_users  registered_users  total_users
# 0             Clear    964.030238       3912.755940  4876.786177
# 1        Light Snow    185.476190       1617.809524  1803.285714
# 2              Mist    687.352227       3348.510121  4035.862348

# %%
# Melihat tren penggunaan sepeda berdasarkan bulan
tren_penggunaan_per_bulan = day.groupby('month')[['casual_users','registered_users','total_users']].sum().reset_index()
tren_penggunaan_per_bulan
# Out:
#    month  casual_users  registered_users  total_users
# 0    Jan         12042            122891       134933
# 1    Feb         14963            136389       151352
# 2    Mar         44444            184476       228920
# 3    Apr         60802            208292       269094
# 4    May         75285            256401       331686
# 5    Jun         73906            272436       346342
# 6    Jul         78157            266791       344948
# 7    Aug         72039            279155       351194
# 8    Sep         70323            275668       345991
# 9    Oct         59760            262592       322352
# 10   Nov         36603            218228       254831
# 11   Dec         21693            189343       211036

# %%
# Melihat total pengguna sepeda berdasarkan musim dan tahun
total_pengguna_per_musim_tahun = day.groupby(['year', 'season_num'])[['casual_users','registered_users','total_users']].sum().reset_index()
total_pengguna_per_musim_tahun
# Out:
#    year season_num  casual_users  registered_users  total_users
# 0  2011       fall         95450            324200       419650
# 1  2011   springer         21425            128575       150000
# 2  2011     summer         77564            269752       347316
# 3  2011     winter         52813            273324       326137
# 4  2012       fall        130641            510838       641479
# 5  2012   springer         39197            282151       321348
# 6  2012     summer        125958            445315       571273
# 7  2012     winter         76969            438507       515476

# %% [markdown]
# ### Explore Dataset Hour

# %%
# Melihat rata-rata pengguna sepeda berdasarkan jam
rata_rata_pengguna_per_jam = hour.groupby('hour')[['casual_users','registered_users','total_users']].mean().reset_index()
rata_rata_pengguna_per_jam
# Out:
#     hour  casual_users  registered_users  total_users
# 0      0     10.158402         43.739669    53.898072
# 1      1      6.504144         26.871547    33.375691
# 2      2      4.772028         18.097902    22.869930
# 3      3      2.715925          9.011478    11.727403
# 4      4      1.253945          5.098996     6.352941
# 5      5      1.411437         18.478382    19.889819
# 6      6      4.161379         71.882759    76.044138
# 7      7     11.055021        201.009629   212.064649
# 8      8     21.679505        337.331499   359.011004
# 9      9     30.891334        188.418157   219.309491
# 10    10     46.477304        127.191197   173.668501
# 11    11     59.540578        148.602476   208.143054
# 12    12     68.293956        185.021978   253.315934
# 13    13     72.308642        181.352538   253.661180
# 14    14     75.567901        165.381344   240.949246
# 15    15     74.905350        176.327846   251.233196
# ...

# %%
# Melihat total pengguna sepeda berdasarkan hari dan jam
total_pengguna_per_hari_jam = hour.groupby(['day_of_week', 'hour'])['total_users'].sum().reset_index()
total_pengguna_per_hari_jam
# Out:
#     day_of_week  hour  total_users
# 0           Fri     0         5453
# 1           Fri     1         2571
# 2           Fri     2         1325
# 3           Fri     3          673
# 4           Fri     4          589
# ..          ...   ...          ...
# 163         Wed    19        36823
# 164         Wed    20        26436
# 165         Wed    21        20051
# 166         Wed    22        14800
# 167         Wed    23         8625
#
# [168 rows x 3 columns]

# %%
# Melihat rata-rata pengguna sepeda berdasarkan kondisi cuaca dan jam
rata_rata_pengguna_per_kondisi_cuaca_jam = hour.groupby(['weather_condition', 'hour'])['total_users'].mean().reset_index()
rata_rata_pengguna_per_kondisi_cuaca_jam
# Out:
#    weather_condition  hour  total_users
# 0              Clear     0    59.161554
# 1              Clear     1    34.395918
# 2              Clear     2    22.817992
# 3              Clear     3    11.995604
# 4              Clear     4     6.413567
# ..               ...   ...          ...
# 70              Mist    19   282.025000
# 71              Mist    20   204.542857
# 72              Mist    21   151.816456
# 73              Mist    22   116.823171
# 74              Mist    23    85.171598
#
# [75 rows x 3 columns]

# %%
# Melihat tren penggunaan sepeda berdasarkan bulan dan jam
tren_penggunaan_per_bulan_jam = hour.groupby(['month', 'hour'])['total_users'].sum().reset_index()
tren_penggunaan_per_bulan_jam
# Out:
#     month  hour  total_users
# 0     Jan     0         1462
# 1     Jan     1         1029
# 2     Jan     2          763
# 3     Jan     3          383
# 4     Jan     4          162
# ..    ...   ...          ...
# 283   Dec    19        12437
# 284   Dec    20         8805
# 285   Dec    21         6935
# 286   Dec    22         5169
# 287   Dec    23         3724
#
# [288 rows x 3 columns]

# %%
# Melihat total pengguna sepeda berdasarkan musim, tahun, dan jam
total_pengguna_per_musim_tahun_jam = hour.groupby(['year', 'season_num', 'hour'])['total_users'].sum().reset_index()
total_pengguna_per_musim_tahun_jam
# Out:
#      year season_num  hour  total_users
# 0    2011       fall     0         5679
# 1    2011       fall     1         3352
# 2    2011       fall     2         2406
# 3    2011       fall     3         1301
# 4    2011       fall     4          629
# ..    ...        ...   ...          ...
# 187  2012     winter    19        31920
# 188  2012     winter    20        22753
# 189  2012     winter    21        16974
# 190  2012     winter    22        12769
# 191  2012     winter    23         9120
#
# [192 rows x 4 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
import matplotlib.pyplot as plt
#membuat dataframe baru untuk agregasi data
monthly_counts = day.groupby('month')[['casual_users', 'registered_users']].sum().reset_index()

#membuat visualisasi data
plt.figure(figsize=(12, 6))
plt.plot(monthly_counts['month'], monthly_counts['casual_users'], label='Casual Users', marker='o')
plt.plot(monthly_counts['month'], monthly_counts['registered_users'], label='Registered Users', marker='o')
plt.xlabel('Month')
plt.ylabel('Number of Users')
plt.title('Monthly Trend of Bike Usage')
plt.legend()
plt.grid(True)

#menambahkan titik titik penjelas untuk setiap bulan
for i, month in enumerate(monthly_counts['month']):
    plt.annotate('.', (month, monthly_counts['casual_users'][i]), textcoords="offset points", xytext=(0,10), ha='center')
    plt.annotate('.', (month, monthly_counts['registered_users'][i]), textcoords="offset points", xytext=(0,10), ha='center')

plt.show()

#menampilkan tabel data
print(monthly_counts)
# Out:
#    month  casual_users  registered_users
# 0    Jan         12042            122891
# 1    Feb         14963            136389
# 2    Mar         44444            184476
# 3    Apr         60802            208292
# 4    May         75285            256401
# 5    Jun         73906            272436
# 6    Jul         78157            266791
# 7    Aug         72039            279155
# 8    Sep         70323            275668
# 9    Oct         59760            262592
# 10   Nov         36603            218228
# 11   Dec         21693            189343

# %% [markdown]
# Berdasarkan visualisasi dan tabel di atas, dapat disimpulkan bahwa tren penggunaan sepeda secara bulanan menunjukkan pola musiman.
# Jumlah pengguna, baik casual maupun registered, cenderung meningkat pada bulan-bulan musim hangat (Mei hingga Oktober) dan menurun pada bulan-bulan musim dingin (November hingga April).
# Peningkatan penggunaan sepeda pada musim hangat mungkin disebabkan oleh cuaca yang lebih baik dan kondisi bersepeda yang lebih nyaman.
# Penurunan penggunaan sepeda pada musim dingin mungkin disebabkan oleh cuaca yang lebih dingin dan kondisi bersepeda yang kurang nyaman.
# Secara umum, jumlah pengguna registered lebih tinggi daripada pengguna casual di setiap bulan.
# Hal ini menunjukkan bahwa sebagian besar pengguna sepeda adalah pengguna terdaftar yang mungkin menggunakan sepeda untuk keperluan transportasi sehari-hari, seperti berangkat kerja atau sekolah.
# Pengguna casual mungkin lebih banyak menggunakan sepeda untuk keperluan rekreasi atau wisata.

# %% [markdown]
# ### Pertanyaan 2:

# %%
import matplotlib.pyplot as plt
# Membuat dataframe baru untuk agregasi data berdasarkan musim dan kondisi cuaca
seasonal_weather_counts = day.groupby(['season_num', 'weather_condition'])['total_users'].sum().reset_index()

# Membuat visualisasi data
plt.figure(figsize=(12, 6))
sns.barplot(x='season_num', y='total_users', hue='weather_condition', data=seasonal_weather_counts)
plt.xlabel('Season')
plt.ylabel('Total Number of Users')
plt.title('Impact of Season and Weather on Bike Usage')
plt.legend()
plt.grid(True)
plt.show()

# Menampilkan tabel data
print(seasonal_weather_counts)
# Out:
#    season_num weather_condition  total_users
# 0        fall             Clear       799443
# 1        fall        Light Snow        11007
# 2        fall              Mist       250679
# 3    springer             Clear       312036
# 4    springer        Light Snow         3739
# 5    springer              Mist       155573
# 6      summer             Clear       626986
# 7      summer        Light Snow         3507
# 8      summer              Mist       288096
# 9      winter             Clear       519487
# 10     winter        Light Snow        19616
# 11     winter              Mist       302510

# %% [markdown]
# Berdasarkan visualisasi dan tabel di atas, dapat disimpulkan bahwa musim dan cuaca memiliki dampak yang signifikan terhadap penggunaan sepeda.
# Pada umumnya, penggunaan sepeda tertinggi terjadi pada musim gugur, diikuti oleh musim panas, musim semi, dan terakhir musim dingin.
# Hal ini mungkin disebabkan oleh suhu yang lebih nyaman dan kondisi cuaca yang lebih baik pada musim gugur dan musim panas.
# Kondisi cuaca juga memiliki pengaruh yang besar terhadap penggunaan sepeda.
# Pada setiap musim, penggunaan sepeda tertinggi terjadi pada saat cuaca cerah (Clear), diikuti oleh cuaca berkabut (Mist), salju ringan (Light Snow), dan terakhir hujan lebat (Heavy Rain).
# Hal ini menunjukkan bahwa orang cenderung lebih suka bersepeda saat cuaca cerah dan menghindari bersepeda saat cuaca buruk

# %% [markdown]
# ### pertanyaan 3:

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Menghitung nilai Recency, Frequency, dan Monetary untuk setiap pengguna
# Karena dataset tidak memiliki informasi transaksi, kita akan menggunakan 'date_day' sebagai proxy untuk Recency,
# jumlah perjalanan sebagai proxy untuk Frequency, dan total pengguna sebagai proxy untuk Monetary.

# Mengambil tanggal terakhir dalam dataset
snapshot_date = day['date_day'].max() + pd.Timedelta(days=1)

# Menghitung RFM untuk pengguna casual
rfm_casual = day.groupby('record_id').agg({
    'date_day': lambda x: (snapshot_date - x.max()).days,  # Recency
    'casual_users': 'sum',  # Frequency
    'total_users': 'sum'  # Monetary
}).rename(columns={
    'date_day': 'Recency',
    'casual_users': 'Frequency',
    'total_users': 'Monetary'
})

# Menghitung RFM untuk pengguna registered
rfm_registered = day.groupby('record_id').agg({
    'date_day': lambda x: (snapshot_date - x.max()).days,  # Recency
    'registered_users': 'sum',  # Frequency
    'total_users': 'sum'  # Monetary
}).rename(columns={
    'date_day': 'Recency',
    'registered_users': 'Frequency',
    'total_users': 'Monetary'
})

# Menentukan skor RFM (1-4) berdasarkan quartile
# Semakin rendah skor Recency, semakin baik. Semakin tinggi skor Frequency dan Monetary, semakin baik.
for df in [rfm_casual, rfm_registered]:
    df['R_Quartile'] = pd.qcut(df['Recency'], q=4, labels=range(4, 0, -1))
    df['F_Quartile'] = pd.qcut(df['Frequency'], q=4, labels=range(1, 5))
    df['M_Quartile'] = pd.qcut(df['Monetary'], q=4, labels=range(1, 5))

# Menggabungkan skor RFM menjadi satu skor
rfm_casual['RFM_Score'] = rfm_casual['R_Quartile'].astype(str) + rfm_casual['F_Quartile'].astype(str) + rfm_casual['M_Quartile'].astype(str)
rfm_registered['RFM_Score'] = rfm_registered['R_Quartile'].astype(str) + rfm_registered['F_Quartile'].astype(str) + rfm_registered['M_Quartile'].astype(str)

# Membuat segmentasi pelanggan berdasarkan skor RFM
def segment_customer(df):
    if df['RFM_Score'] >= '444':
        return 'Champions'
    elif df['RFM_Score'] >= '333':
        return 'Loyal Customers'
    elif df['RFM_Score'] >= '222':
        return 'Potential Loyalists'
    elif df['RFM_Score'] >= '111':
        return 'New Customers'
    else:
        return 'At Risk'

rfm_casual['Segment'] = rfm_casual.apply(segment_customer, axis=1)
rfm_registered['Segment'] = rfm_registered.apply(segment_customer, axis=1)

# Visualisasi distribusi segmen pelanggan
plt.figure(figsize=(10, 6))
sns.countplot(x='Segment', data=rfm_casual, order=['Champions', 'Loyal Customers', 'Potential Loyalists', 'New Customers', 'At Risk'])
plt.title('Customer Segmentation for Casual Users')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='Segment', data=rfm_registered, order=['Champions', 'Loyal Customers', 'Potential Loyalists', 'New Customers', 'At Risk'])
plt.title('Customer Segmentation for Registered Users')
plt.xticks(rotation=45)
plt.show()

# Menampilkan tabel RFM dan segmentasi
print("RFM and Segmentation for Casual Users:")
print(rfm_casual.head())
print("\n")
print("RFM and Segmentation for Registered Users:")
print(rfm_registered.head())
# Out:
# RFM and Segmentation for Casual Users:
#            Recency  Frequency  Monetary R_Quartile F_Quartile M_Quartile  \
# record_id
# 1              731        331       985          1          2          1
# 2              730        131       801          1          1          1
# 3              729        120      1349          1          1          1
# 4              728        108      1562          1          1          1
# 5              727         82      1600          1          1          1
#
#           RFM_Score        Segment
# record_id
# 1               121  New Customers
# 2               111  New Customers
# 3               111  New Customers
# 4               111  New Customers
# 5               111  New Customers
#
#
# RFM and Segmentation for Registered Users:
#            Recency  Frequency  Monetary R_Quartile F_Quartile M_Quartile  \
# record_id
# 1              731        654       985          1          1          1
# ...

# %% [markdown]
# Berdasarkan analisis RFM dan visualisasi di atas, dapat disimpulkan bahwa:
# - Pengguna casual sebagian besar termasuk dalam segmen 'New Customers' dan 'Potential Loyalists'. Ini menunjukkan bahwa sebagian besar pengguna casual adalah pengguna baru atau pengguna yang belum sering menggunakan layanan berbagi sepeda.
# - Pengguna registered sebagian besar termasuk dalam segmen 'Loyal Customers' dan 'Champions'. Ini menunjukkan bahwa sebagian besar pengguna registered adalah pengguna setia yang sering menggunakan layanan berbagi sepeda.
# - Strategi pemasaran yang berbeda dapat diterapkan untuk setiap segmen. Misalnya, pengguna casual dapat ditargetkan dengan promosi dan diskon untuk mendorong mereka menggunakan layanan lebih sering. Pengguna registered dapat ditargetkan dengan program loyalitas dan penawaran eksklusif untuk mempertahankan loyalitas mereka

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
#
# Berdasarkan visualisasi dan tabel di atas, dapat disimpulkan bahwa tren penggunaan sepeda secara bulanan menunjukkan pola musiman.
# Jumlah pengguna, baik casual maupun registered, cenderung meningkat pada bulan-bulan musim hangat (Mei hingga Oktober) dan menurun pada bulan-bulan musim dingin (November hingga April).
# Peningkatan penggunaan sepeda pada musim hangat mungkin disebabkan oleh cuaca yang lebih baik dan kondisi bersepeda yang lebih nyaman.
# Penurunan penggunaan sepeda pada musim dingin mungkin disebabkan oleh cuaca yang lebih dingin dan kondisi bersepeda yang kurang nyaman.
# Secara umum, jumlah pengguna registered lebih tinggi daripada pengguna casual di setiap bulan.
# Hal ini menunjukkan bahwa sebagian besar pengguna sepeda adalah pengguna terdaftar yang mungkin menggunakan sepeda untuk keperluan transportasi sehari-hari, seperti berangkat kerja atau sekolah.
# Pengguna casual mungkin lebih banyak menggunakan sepeda untuk keperluan rekreasi atau wisata.
#
# - Conclution pertanyaan 2
#
# Berdasarkan visualisasi dan tabel di atas, dapat disimpulkan bahwa musim dan cuaca memiliki dampak yang signifikan terhadap penggunaan sepeda.
# Pada umumnya, penggunaan sepeda tertinggi terjadi pada musim gugur, diikuti oleh musim panas, musim semi, dan terakhir musim dingin.
# Hal ini mungkin disebabkan oleh suhu yang lebih nyaman dan kondisi cuaca yang lebih baik pada musim gugur dan musim panas.
# Kondisi cuaca juga memiliki pengaruh yang besar terhadap penggunaan sepeda.
# Pada setiap musim, penggunaan sepeda tertinggi terjadi pada saat cuaca cerah (Clear), diikuti oleh cuaca berkabut (Mist), salju ringan (Light Snow), dan terakhir hujan lebat (Heavy Rain).
# Hal ini menunjukkan bahwa orang cenderung lebih suka bersepeda saat cuaca cerah dan menghindari bersepeda saat cuaca buruk
#
#
# - Conclution pertanyaan 3
#
# Berdasarkan analisis RFM dan visualisasi di atas, dapat disimpulkan bahwa:
# - Pengguna casual sebagian besar termasuk dalam segmen 'New Customers' dan 'Potential Loyalists'. Ini menunjukkan bahwa sebagian besar pengguna casual adalah pengguna baru atau pengguna yang belum sering menggunakan layanan berbagi sepeda.
# - Pengguna registered sebagian besar termasuk dalam segmen 'Loyal Customers' dan 'Champions'. Ini menunjukkan bahwa sebagian besar pengguna registered adalah pengguna setia yang sering menggunakan layanan berbagi sepeda.
# - Strategi pemasaran yang berbeda dapat diterapkan untuk setiap segmen. Misalnya, pengguna casual dapat ditargetkan dengan promosi dan diskon untuk mendorong mereka menggunakan layanan lebih sering. Pengguna registered dapat ditargetkan dengan program loyalitas dan penawaran eksklusif untuk mempertahankan loyalitas mereka
